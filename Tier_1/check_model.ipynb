# %%
import subprocess

result = subprocess.run(
    ["ollama", "ps"],
    capture_output=True,
    text=True,
    check=True,
)
print(result.stdout)
# Out:
# NAME           ID              SIZE      PROCESSOR    CONTEXT    UNTIL
# llama3.2:1b    baf6a787fdff    1.5 GB    100% GPU     4096       3 minutes from now

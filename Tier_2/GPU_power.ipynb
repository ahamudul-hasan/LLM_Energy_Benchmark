# %%
from pynvml import *

nvmlInit()

handle = nvmlDeviceGetHandleByIndex(0)

power = nvmlDeviceGetPowerUsage(handle)

print(f"GPU Power Usage: {power / 1000:.2f} W")

nvmlShutdown()
# Out:
# GPU Power Usage: 61.54 W

# %%
# !nvidia-smi
# Out:
# Sat Sep  5 23:56:10 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 610.88                 KMD Version: 610.88        CUDA UMD Version: 13.3     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 Ti   WDDM  |   00000000:07:00.0  On |                  N/A |
# | 34%   41C    P8             17W /  225W |     954MiB /   8192MiB |      6%      Default |
# |                                         |                        |                  N/A |
# ...
